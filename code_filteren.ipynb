# %% [markdown]
# <a href="https://colab.research.google.com/github/pastatimes/Master-Thesis-HateSpeech-Twitter/blob/master/code_filteren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Data laden in geschikt format
import pandas as pd

data = pd.read_excel("/content/drive/My Drive/Colab Notebooks/Filtered dataset/2015_gefiltered vanaf juni.xlsx") # Zelf je eigen pad naar het bestand aanpassen
data
# Out:
#                       id  ... geo
# 0     610704372415229056  ... NaN
# 1     610704441872882944  ... NaN
# 2     610710557285555968  ... NaN
# 3     610710626269305984  ... NaN
# 4     610710697140440960  ... NaN
# ...                  ...  ...  ..
# 3846  682267088271110016  ... NaN
# 3847  682291228898114944  ... NaN
# 3848  682297346240167040  ... NaN
# 3849  682310784563719936  ... NaN
# 3850  682319510251159040  ... NaN
#
# [3851 rows x 9 columns]

# %%
# klein voorbeeld van keyword lijst
keywords = keywords = ['illegals', 'illegal immigrants', 'immigrants', 'migrants', 'refugees', 'Hillary Clinton', 'Hillary', 'Clinton', 'Democrats', 'dishonest media', 'fake news media', 'gay', 'gays', 'woman', 'women', 'Democrats', 'Democrat Congresswomen', 'why don’t they go back', 'bring them back from where they came', 'China', 'Chinese', 'blacks', 'black people', 'Hispanics', 'Mexicans', 'Mexico', 'Mexican', 'drug dealers', 'liar', 'liars', 'cartels', 'crazy people', 'crazy', 'stupid', 'human traffickers', 'coyotes', 'border', 'wall', 'invasion', 'fools', 'infestation', 'abuser', 'shithole countries', 'Muslims', 'Islam', 'ISIS', 'terrorist', 'terrorists', 'nuclear war', 'Korea', 'Russia', 'Russians', 'Iran', 'Iraq', 'virus', 'fake news', 'ban', 'animal', 'animals', 'rapists', 'gang members', 'asylum', 'these aren’t people', 'clown', 'dummy', 'phony', 'brat', 'pathetic', 'low class', 'rats']

#filter uit de tweets een van deze keywords
filtered_data = data[data['content'].str.contains('|'.join(keywords))]
filtered_data
# Out:
#                 id  ... geo
# 2     6.107110e+17  ... NaN
# 14    6.107120e+17  ... NaN
# 36    6.111690e+17  ... NaN
# 49    6.118650e+17  ... NaN
# 55    6.118670e+17  ... NaN
# ...            ...  ...  ..
# 3788  6.810940e+17  ... NaN
# 3798  6.811550e+17  ... NaN
# 3804  6.814480e+17  ... NaN
# 3816  6.816830e+17  ... NaN
# 3819  6.816940e+17  ... NaN
#
# [509 rows x 9 columns]

# %%
filtered_data.to_excel("/content/drive/My Drive/Colab Notebooks/Keyword_tweets.xlsx")
